# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from os import listdir
from os.path import isfile, join
from scipy import interpolate
from scipy import stats
import seaborn as sns

# %%
# pulling csv file that has country clusters in it
file_country_cluster = "Data2/Metadata_Country_API_NY.GDP.MKTP.CD_DS2_en_csv_v2_10181085.csv"
file_country_cluster_df = pd.read_csv(file_country_cluster)
file_country_cluster_df.head()
# Out:
#   Country Code                     Region          IncomeGroup  \
# 0          ABW  Latin America & Caribbean          High income
# 1          AFG                 South Asia           Low income
# 2          AGO         Sub-Saharan Africa  Lower middle income
# 3          ALB      Europe & Central Asia  Upper middle income
# 4          AND      Europe & Central Asia          High income
#
#                                         SpecialNotes    TableName  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2                                                NaN       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra         NaN

# %%
# pulling csv file that has countryGDP
file_country_gdp = "Data2/GDP_Country.csv"
file_country_gdp_df = pd.read_csv(file_country_gdp, encoding = "ISO-8859-1")
file_country_gdp_df.head()
# Out:
#   Country Name Country Code     Indicator Name  Indicator Code         1960  \
# 0        Aruba          ABW  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 1  Afghanistan          AFG  GDP (current US$)  NY.GDP.MKTP.CD  537777811.1
# 2       Angola          AGO  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 3      Albania          ALB  GDP (current US$)  NY.GDP.MKTP.CD          NaN
# 4      Andorra          AND  GDP (current US$)  NY.GDP.MKTP.CD          NaN
#
#           1961         1962         1963         1964          1965  \
# 0          NaN          NaN          NaN          NaN           NaN
# 1  548888895.6  546666677.8  751111191.1  800000044.4  1.006667e+09
# 2          NaN          NaN          NaN          NaN           NaN
# 3          NaN          NaN          NaN          NaN           NaN
# 4          NaN          NaN          NaN          NaN           NaN
#
#        ...               2008          2009          2010          2011  \
# ...

# %%
# renaming columns to match tobacco file
file_country_cluster_df = file_country_cluster_df.rename(columns={"Country Code": "Code", "TableName": "Entity"})
file_country_cluster_df.head()
# Out:
#   Code                     Region          IncomeGroup  \
# 0  ABW  Latin America & Caribbean          High income
# 1  AFG                 South Asia           Low income
# 2  AGO         Sub-Saharan Africa  Lower middle income
# 3  ALB      Europe & Central Asia  Upper middle income
# 4  AND      Europe & Central Asia          High income
#
#                                         SpecialNotes       Entity  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...        Aruba         NaN
# 1  Fiscal year end: March 20; reporting period fo...  Afghanistan         NaN
# 2                                                NaN       Angola         NaN
# 3                                                NaN      Albania         NaN
# 4  WB-3 code changed from ADO to AND to align wit...      Andorra         NaN

# %%
# Moving years to rows and keeping countries as row- creating gdp_DF
my_years = list(file_country_gdp_df.columns.values[4:])
gdp_df = pd.melt(file_country_gdp_df,id_vars="Country Code",value_vars=my_years,var_name="year",value_name="GDP")
gdp_df.head()
# Out:
#   Country Code  year          GDP
# 0          ABW  1960          NaN
# 1          AFG  1960  537777811.1
# 2          AGO  1960          NaN
# 3          ALB  1960          NaN
# 4          AND  1960          NaN

# %%
new_with_cluster_GDP_df = pd.merge(gdp_df, file_country_cluster_df, left_on="Country Code", right_on="Code")
new_with_cluster_GDP_df.head()
# Out:
#   Country Code  year  GDP Code                     Region  IncomeGroup  \
# 0          ABW  1960  NaN  ABW  Latin America & Caribbean  High income
# 1          ABW  1961  NaN  ABW  Latin America & Caribbean  High income
# 2          ABW  1962  NaN  ABW  Latin America & Caribbean  High income
# 3          ABW  1963  NaN  ABW  Latin America & Caribbean  High income
# 4          ABW  1964  NaN  ABW  Latin America & Caribbean  High income
#
#                                         SpecialNotes Entity  Unnamed: 5
# 0  SNA data for 2000-2011 are updated from offici...  Aruba         NaN
# 1  SNA data for 2000-2011 are updated from offici...  Aruba         NaN
# 2  SNA data for 2000-2011 are updated from offici...  Aruba         NaN
# 3  SNA data for 2000-2011 are updated from offici...  Aruba         NaN
# 4  SNA data for 2000-2011 are updated from offici...  Aruba         NaN

# %%
mypath = 'Data'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
onlyfiles
# Out:
# ['smoking-deaths-by-age.csv',
#  'share-of-men-who-are-smoking.csv',
#  'number-of-deaths-from-tobacco-smoking.csv',
#  'number-of-total-daily-smokers.csv',
#  'consumption-per-smoker-per-day.csv',
#  'share-of-women-who-are-smoking.csv',
#  'average-price-of-a-pack-of-cigarettes.csv']

# %%
dfs = [pd.read_csv("Data/" + x) for x in onlyfiles]

# %%
for df in dfs:
    print(df.columns.values)
# Out:
# ['Entity' 'Code' 'Year' '70+ years old (deaths)'
#  '15-49 years old (deaths)' '50-69 years old (deaths)']
# ['Entity' 'Code' 'Year' ' (% of adults)']
# ['Entity' 'Code' 'Year' 'Tobacco smoking']
# ['Entity' 'Code' 'Year'
#  'Number of daily smokers - both (IHME, GHDx (2012))']
# ['Entity' 'Code' 'Year'
#  'Cigarette consumption per smoker per day (cigarettes)']
# ['Entity' 'Code' 'Year' ' (% of adults)']
# ['Entity' 'Code' 'Year'
#  'Indicator:Average -  cigarette price in international dollars (international-$)']

# %%
df_new = pd.DataFrame(columns= ['Entity','Code',"Year"])
for df in dfs:
    df_new = pd.merge(df_new,df,how = 'outer', on =['Entity','Code','Year'])

# %%
df_new
# Out:
#                      Entity Code  Year  70+ years old (deaths)  \
# 0               Afghanistan  AFG  1990             1246.238030
# 1               Afghanistan  AFG  1995             1974.935625
# 2               Afghanistan  AFG  2000             2429.371353
# 3               Afghanistan  AFG  2005             2848.213811
# 4               Afghanistan  AFG  2006             2951.940806
# 5               Afghanistan  AFG  2010             3306.430594
# 6               Afghanistan  AFG  2016             4057.745075
# 7                   Albania  ALB  1990             1118.952520
# 8                   Albania  ALB  1995             1210.307920
# 9                   Albania  ALB  2000             1471.491695
# 10                  Albania  ALB  2005             1741.660183
# 11                  Albania  ALB  2006             1766.572255
# 12                  Albania  ALB  2010             1899.232345
# 13                  Albania  ALB  2016             2063.992007
# ...

# %%
# Showing the new dateset with clusters (Income Group)
new_with_cluster_df = pd.merge(df_new, new_with_cluster_GDP_df, on=["Code", 'Entity'])
new_with_cluster_df.head()
# Out:
#         Entity Code  Year  70+ years old (deaths)  15-49 years old (deaths)  \
# 0  Afghanistan  AFG  1990              1246.23803                2053.68507
# 1  Afghanistan  AFG  1990              1246.23803                2053.68507
# 2  Afghanistan  AFG  1990              1246.23803                2053.68507
# 3  Afghanistan  AFG  1990              1246.23803                2053.68507
# 4  Afghanistan  AFG  1990              1246.23803                2053.68507
#
#    50-69 years old (deaths)   (% of adults)_x  Tobacco smoking  \
# 0               3497.160641               NaN           6797.0
# 1               3497.160641               NaN           6797.0
# 2               3497.160641               NaN           6797.0
# 3               3497.160641               NaN           6797.0
# 4               3497.160641               NaN           6797.0
#
#    Number of daily smokers - both (IHME, GHDx (2012))  \
# 0                                           652030.0
# ...

# %%
# Number of countries
number_countries = new_with_cluster_df["Code"].nunique()
number_countries
# Out:
# 168

# %%
# Showing the cluster types
new_with_cluster_df["IncomeGroup"].value_counts()
# Out:
# High income            105444
# Upper middle income     96686
# Lower middle income     71688
# Low income              57188
# Name: IncomeGroup, dtype: int64

# %%
clean_df = new_with_cluster_df[["Code","Cigarette consumption per smoker per day (cigarettes)", 
                                                   "GDP", "year", "IncomeGroup"]].dropna()

clean_df
    


# population_UpperMid_Inc = [clean_df["IncomeGroup"] == "Upper middle income"]



# population_UpperMid_Inc["Cigarette consumption per smoker per day (cigarettes)"].mean()
# Out:
#        Code  Cigarette consumption per smoker per day (cigarettes)  \
# 0       AFG                                                5.8
# 1       AFG                                                5.8
# 2       AFG                                                5.8
# 3       AFG                                                5.8
# 4       AFG                                                5.8
# 5       AFG                                                5.8
# 6       AFG                                                5.8
# 7       AFG                                                5.8
# 8       AFG                                                5.8
# 9       AFG                                                5.8
# 10      AFG                                                5.8
# 11      AFG                                                5.8
# 12      AFG                                                5.8
# 13      AFG                                                5.8
# ...

# %%
#tells us how many missing values there are per column
df_new.isnull().sum()
# Out:
# Entity                                                                                0
# Code                                                                                419
# Year                                                                                  0
# 70+ years old (deaths)                                                             5519
# 15-49 years old (deaths)                                                           5519
# 50-69 years old (deaths)                                                           5519
#  (% of adults)_x                                                                   6286
# Tobacco smoking                                                                    5519
# Number of daily smokers - both (IHME, GHDx (2012))                                  876
# Cigarette consumption per smoker per day (cigarettes)                               876
#  (% of adults)_y                                                                   6271
# ...

# %%
#gives the breakdown of the countries
df_new['Entity'].value_counts()
# Out:
# United Kingdom                                       36
# Panama                                               36
# Thailand                                             36
# Uganda                                               36
# Ghana                                                36
# Senegal                                              36
# Israel                                               36
# Chile                                                36
# Italy                                                36
# Greece                                               36
# Moldova                                              36
# Uzbekistan                                           36
# Croatia                                              36
# Comoros                                              36
# Germany                                              36
# Bangladesh                                           36
# India                                                36
# ...

# %%
##I think our best bet is to try and manually filter the dataset to select the values we want, by combing we skew our data
#and make it hard to decifer

# %%
#shows us the rows where we are missing values
df_new[df_new['Tobacco smoking'].notnull()]
# Out:
#                Entity Code  Year  70+ years old (deaths)  \
# 0         Afghanistan  AFG  1990             1246.238030
# 1         Afghanistan  AFG  1995             1974.935625
# 2         Afghanistan  AFG  2000             2429.371353
# 3         Afghanistan  AFG  2005             2848.213811
# 4         Afghanistan  AFG  2006             2951.940806
# 5         Afghanistan  AFG  2010             3306.430594
# 6         Afghanistan  AFG  2016             4057.745075
# 7             Albania  ALB  1990             1118.952520
# 8             Albania  ALB  1995             1210.307920
# 9             Albania  ALB  2000             1471.491695
# 10            Albania  ALB  2005             1741.660183
# 11            Albania  ALB  2006             1766.572255
# 12            Albania  ALB  2010             1899.232345
# 13            Albania  ALB  2016             2063.992007
# 14            Algeria  DZA  1990             3007.505428
# ...

# %%
tobaccosmoke  = df_new[['Tobacco smoking','Entity','Year']].dropna()

# %%
x = tobaccosmoke['Year']
y= tobaccosmoke['Tobacco smoking']
z = tobaccosmoke['Entity']
#plt.bar(x,y)

# %%
tobaccosmoke.groupby('Entity')
#tobaccosmoke.value_counts()

# %%
#trying to rename some of the columns
rename_df = df_new.rename(index= str, columns= {"Tobacco smoking":"Tobacco Smoking Deaths", 
                                                'Number of daily smokers - both (IHME, GHDx (2012))':'Number of Daily Smokers',
                                                'Cigarette consumption per smoker per day (cigarettes)': 'Cigarette Consumption per smoker per day'} )
rename_df
# Out:
#                      Entity Code  Year  70+ years old (deaths)  \
# 0               Afghanistan  AFG  1990             1246.238030
# 1               Afghanistan  AFG  1995             1974.935625
# 2               Afghanistan  AFG  2000             2429.371353
# 3               Afghanistan  AFG  2005             2848.213811
# 4               Afghanistan  AFG  2006             2951.940806
# 5               Afghanistan  AFG  2010             3306.430594
# 6               Afghanistan  AFG  2016             4057.745075
# 7                   Albania  ALB  1990             1118.952520
# 8                   Albania  ALB  1995             1210.307920
# 9                   Albania  ALB  2000             1471.491695
# 10                  Albania  ALB  2005             1741.660183
# 11                  Albania  ALB  2006             1766.572255
# 12                  Albania  ALB  2010             1899.232345
# 13                  Albania  ALB  2016             2063.992007
# ...

# %%
#tells us how many missing values there are per columnr
rename_df.isnull().sum()
# Out:
# Entity                                                                                0
# Code                                                                                419
# Year                                                                                  0
# 70+ years old (deaths)                                                             5519
# 15-49 years old (deaths)                                                           5519
# 50-69 years old (deaths)                                                           5519
#  (% of adults)_x                                                                   6286
# Tobacco Smoking Deaths                                                             5519
# Number of Daily Smokers                                                             876
# Cigarette Consumption per smoker per day                                            876
#  (% of adults)_y                                                                   6271
# ...

# %%
#gives the breakdown of the countries
rename_df['Entity'].value_counts()
# Out:
# United Kingdom                                       36
# Panama                                               36
# Thailand                                             36
# Uganda                                               36
# Ghana                                                36
# Senegal                                              36
# Israel                                               36
# Chile                                                36
# Italy                                                36
# Greece                                               36
# Moldova                                              36
# Uzbekistan                                           36
# Croatia                                              36
# Comoros                                              36
# Germany                                              36
# Bangladesh                                           36
# India                                                36
# ...

# %%
##I think our best bet is to try and manually filter the dataset to select the values we want, by combing we skew our data
#and make it hard to decifer

# %%
#shows us the rows where we are missing values
rename_df[rename_df['Tobacco Smoking Deaths'].notnull()]
# Out:
#                Entity Code  Year  70+ years old (deaths)  \
# 0         Afghanistan  AFG  1990             1246.238030
# 1         Afghanistan  AFG  1995             1974.935625
# 2         Afghanistan  AFG  2000             2429.371353
# 3         Afghanistan  AFG  2005             2848.213811
# 4         Afghanistan  AFG  2006             2951.940806
# 5         Afghanistan  AFG  2010             3306.430594
# 6         Afghanistan  AFG  2016             4057.745075
# 7             Albania  ALB  1990             1118.952520
# 8             Albania  ALB  1995             1210.307920
# 9             Albania  ALB  2000             1471.491695
# 10            Albania  ALB  2005             1741.660183
# 11            Albania  ALB  2006             1766.572255
# 12            Albania  ALB  2010             1899.232345
# 13            Albania  ALB  2016             2063.992007
# 14            Algeria  DZA  1990             3007.505428
# ...

# %%
tobaccosmoke  = rename_df[['Tobacco Smoking Deaths','Entity','Year']].dropna()
tobaccosmoke.head()
# Out:
#    Tobacco Smoking Deaths       Entity  Year
# 0                  6797.0  Afghanistan  1990
# 1                 10589.0  Afghanistan  1995
# 2                 12987.0  Afghanistan  2000
# 3                 15870.0  Afghanistan  2005
# 4                 16337.0  Afghanistan  2006

# %%
#want to drop some of the rows and focus only on columns
pd.set_option('display.precision',2)
deathgroup = tobaccosmoke.groupby('Entity').mean()
#want to drop some of these rows

# %%
tobaccosmoke  = rename_df[['Tobacco Smoking Deaths','Entity','Year']].dropna()
deathgroup = tobaccosmoke.groupby('Entity').mean()
deathgroup.shape
# Out:
# (223, 2)

# %%
deathgroup.drop_duplicates()
# Out:
#                               Tobacco Smoking Deaths     Year
# Entity
# Afghanistan                                 1.45e+04  2003.14
# Albania                                     3.05e+03  2003.14
# Algeria                                     9.33e+03  2003.14
# American Samoa                              3.97e+01  2003.14
# Andorra                                     7.24e+01  2003.14
# Angola                                      3.88e+03  2003.14
# Antigua and Barbuda                         1.07e+01  2003.14
# Argentina                                   4.18e+04  2003.14
# Armenia                                     4.67e+03  2003.14
# Australia                                   1.95e+04  2003.14
# Austria                                     9.97e+03  2003.14
# Azerbaijan                                  7.63e+03  2003.14
# Bahamas                                     1.21e+02  2003.14
# Bahrain                                     2.70e+02  2003.14
# ...

# %%
#25th percentile of the group 
np.percentile(deathgroup['Tobacco Smoking Deaths'],25)
# Out:
# 1040.4285714285713

# %%
np.percentile(deathgroup['Tobacco Smoking Deaths'],75)
# Out:
# 25040.714285714286

# %%
np.percentile(deathgroup['Tobacco Smoking Deaths'],100)
# Out:
# 5912885.142857143

# %%
deathgroup['Tobacco Smoking Deaths'].mean()
# Out:
# 112497.12427930813

# %%
sns.boxplot('Tobacco Smoking Deaths', data= deathgroup)

# %%
#there is a space between the quote opening and the paren
maleperc = rename_df[[' (% of adults)_x','Entity']].dropna()

# %%
femaleperc =  rename_df[[' (% of adults)_y','Entity']].dropna()

# %%
#average Deaths for each country
smokedeath = deathgroup['Tobacco Smoking Deaths']
smokedeathdf= smokedeath.to_frame()

# %%
maleregressdata = pd.merge(smokedeathdf, maleperc, on= 'Entity')
maleregressdata
# Out:
#          Entity  Tobacco Smoking Deaths   (% of adults)_x
# 0       Albania                3.05e+03             56.90
# 1       Albania                3.05e+03             54.70
# 2       Albania                3.05e+03             53.10
# 3       Albania                3.05e+03             52.10
# 4       Albania                3.05e+03             51.20
# 5       Andorra                7.24e+01             43.60
# 6       Andorra                7.24e+01             41.30
# 7       Andorra                7.24e+01             39.20
# 8       Andorra                7.24e+01             38.50
# 9       Andorra                7.24e+01             37.20
# 10    Argentina                4.18e+04             43.70
# 11    Argentina                4.18e+04             38.20
# 12    Argentina                4.18e+04             33.40
# 13    Argentina                4.18e+04             31.80
# 14    Argentina                4.18e+04             29.50
# ...

# %%
#running the regression
smoke_slope, smoke_int, smoke_r, smoke_p, smoke_std_err = stats.linregress(maleregressdata['Tobacco Smoking Deaths'], maleregressdata[' (% of adults)_x'])
smoke_fit = smoke_slope * maleregressdata['Tobacco Smoking Deaths'] + smoke_int

# %%
#plotting the regression line using seaborn
sns.regplot(' (% of adults)_x','Tobacco Smoking Deaths', data =maleregressdata, truncate= False, color = 'blue', scatter= True, robust= True)

# %%
femaleregressdata = pd.merge(smokedeathdf, femaleperc, on= 'Entity')
femaleregressdata
# Out:
#          Entity  Tobacco Smoking Deaths   (% of adults)_y
# 0       Albania                3.05e+03             11.60
# 1       Albania                3.05e+03             10.10
# 2       Albania                3.05e+03              8.70
# 3       Albania                3.05e+03              8.20
# 4       Albania                3.05e+03              7.60
# 5       Andorra                7.24e+01             31.60
# 6       Andorra                7.24e+01             30.20
# 7       Andorra                7.24e+01             28.80
# 8       Andorra                7.24e+01             28.40
# 9       Andorra                7.24e+01             27.80
# 10    Argentina                4.18e+04             34.00
# 11    Argentina                4.18e+04             27.70
# 12    Argentina                4.18e+04             22.40
# 13    Argentina                4.18e+04             20.80
# 14    Argentina                4.18e+04             18.40
# ...

# %%
#plotting the regression line using seaborn
sns.regplot(' (% of adults)_y','Tobacco Smoking Deaths', data =femaleregressdata, truncate= False, color = 'blue', scatter= True, robust= True)

# %%
#a = rename_df[['Cigarette Consumption per smoker per day', 'Entity', 'Code']].dropna()
#a['Cigarette Consumption per smoker per day'].value_counts()
