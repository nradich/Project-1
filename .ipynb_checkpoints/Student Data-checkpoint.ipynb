# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from scipy import stats

# %%
#reading the csv files using pandas
student_mat = pd.read_csv('student-mat.csv')
student_por = pd.read_csv('student-por.csv')

# %%
#The merged Data set reduced the number of rows and added a lot of excess info
student_data = pd.merge(student_mat,student_por, how = 'inner', on=[ "school","sex","age","address","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","nursery","internet"])
student_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob ...   \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other ...
# 3     GP   F   15       U     GT3       T     4     2   health  services ...
# 4     GP   F   16       U     GT3       T     3     3    other     other ...
#
#   famrel_y freetime_y  goout_y  Dalc_y  Walc_y health_y absences_y G1_y G2_y  \
# 0        4          3        4       1       1        3          4    0   11
# 1        5          3        3       1       1        3          2    9   11
# 2        4          3        2       2       3        3          6   12   13
# 3        3          2        2       1       1        5          0   14   14
# 4        4          3        2       1       2        5          0   11   13
#
#   G3_y
# 0   11
# 1   11
# 2   12
# ...

# %%
student_math = student_mat.rename(columns= {'school':'School',
                                           'famsize':'Family Size',
                                           'Pstatus': 'Parent Cohabitation Status',
                                           'Medu':"Mother's Education",
                                           'Fedu': "Father's Education",
                                           'Mjob': "Mother's Job",
                                           'Fjob': "Father's Job",
                                           'Dalc': 'Workday Alcohol Consumption',
                                           'Walc': 'Weekend Alcohol Consumption'})
student_math.head()
# Out:
#   School sex  age address Family Size Parent Cohabitation Status  \
# 0     GP   F   18       U         GT3                          A
# 1     GP   F   17       U         GT3                          T
# 2     GP   F   15       U         LE3                          T
# 3     GP   F   15       U         GT3                          T
# 4     GP   F   16       U         GT3                          T
#
#    Mother's Education  Father's Education Mother's Job Father's Job ...  \
# 0                   4                   4      at_home      teacher ...
# 1                   1                   1      at_home        other ...
# 2                   1                   1      at_home        other ...
# 3                   4                   2       health     services ...
# 4                   3                   3        other        other ...
#
#   famrel freetime  goout  Workday Alcohol Consumption  \
# 0      4        3      4                            1
# ...

# %%
#week consumption more intersting than weekday,expected for young kids
student_math['Workday Alcohol Consumption'].value_counts()
student_math['Weekend Alcohol Consumption'].value_counts()
# Out:
# 1    151
# 2     85
# 3     80
# 4     51
# 5     28
# Name: Weekend Alcohol Consumption, dtype: int64

# %%
#might be better to define the columns earlier
math_age = student_math.iloc[:,2]

math_slope, math_int, math_r, math_p, math_std_err = stats.linregress(student_math['age'], student_math['Weekend Alcohol Consumption'])
math_fit = math_slope * math_age + math_int

# %%
math_fit
# Out:
# 0      2.445464
# 1      2.327098
# 2      2.090367
# 3      2.090367
# 4      2.208733
# 5      2.208733
# 6      2.208733
# 7      2.327098
# 8      2.090367
# 9      2.090367
# 10     2.090367
# 11     2.090367
# 12     2.090367
# 13     2.090367
# 14     2.090367
# 15     2.208733
# 16     2.208733
# 17     2.208733
# 18     2.327098
# 19     2.208733
# 20     2.090367
# 21     2.090367
# 22     2.208733
# 23     2.208733
# 24     2.090367
# 25     2.208733
# 26     2.090367
# 27     2.090367
# 28     2.208733
# 29     2.208733
#          ...
# 365    2.445464
# 366    2.445464
# 367    2.327098
# 368    2.445464
# 369    2.445464
# 370    2.563829
# 371    2.445464
# 372    2.327098
# 373    2.327098
# 374    2.445464
# 375    2.445464
# 376    2.682195
# 377    2.445464
# 378    2.445464
# 379    2.327098
# 380    2.445464
# 381    2.445464
# 382    2.327098
# 383    2.563829
# 384    2.445464
# 385    2.445464
# 386    2.445464
# 387    2.563829
# 388    2.445464
# ...

# %%
#only one 22 and 21 year old
math_age.value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %%
plt.xlim(min(math_age), max(math_age))
plt.plot(math_age,student_math['Weekend Alcohol Consumption'] , linewidth=1, marker="o")
plt.plot(math_age, math_fit, "b--", linewidth=1)
plt.ylabel("Drinking")
# Out:
# Text(0, 0.5, 'Drinking')
