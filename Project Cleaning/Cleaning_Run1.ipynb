# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
deaths_total = pd.read_csv('number-of-deaths-from-tobacco-smoking.csv')
deaths_age = pd.read_csv('smoking-deaths-by-age.csv')

cig_deaths_df = pd.merge(deaths_total, deaths_age, how='outer', on='Entity')
cig_deaths_df.groupby('Entity').describe()
# Out:
#                              15-49 years old (deaths)                 \
#                                                 count           mean
# Entity
# Afghanistan                                      49.0    4134.353694
# Albania                                          49.0     259.250549
# Algeria                                          49.0    1462.743382
# American Samoa                                   49.0      10.035928
# Andean Latin America                              7.0    1676.095764
# Andorra                                          49.0       3.079747
# Angola                                           49.0     935.944015
# Antigua and Barbuda                              49.0       1.514618
# Argentina                                        49.0    3852.662251
# Armenia                                          49.0     532.695420
# Australasia                                       7.0    1123.940646
# ...

# %%
men_smoking_gdp = pd.read_csv('share-of-men-who-are-smoking-by-level-of-prosperity.csv')
men_smoke_gdp = pd.DataFrame(men_smoking_gdp)
men_smoke_gdp.groupby('Entity').head(5)
# Out:
#                Entity      Code  Year  \
# 0         Afghanistan       AFG  1800
# 1         Afghanistan       AFG  1820
# 2         Afghanistan       AFG  1870
# 3         Afghanistan       AFG  1913
# 4         Afghanistan       AFG  1950
# 71            Albania       ALB  1700
# 72            Albania       ALB  1800
# 73            Albania       ALB  1820
# 74            Albania       ALB  1850
# 75            Albania       ALB  1870
# 177           Algeria       DZA  1700
# 178           Algeria       DZA  1800
# 179           Algeria       DZA  1820
# 180           Algeria       DZA  1870
# 181           Algeria       DZA  1913
# 249    American Samoa       ASM  1700
# 250    American Samoa       ASM  1800
# 251    American Samoa       ASM  1850
# 252    American Samoa       ASM  1900
# 253    American Samoa       ASM  1912
# 321           Andorra       AND  1800
# 322           Andorra       AND  1820
# 323           Andorra       AND  1950
# ...
